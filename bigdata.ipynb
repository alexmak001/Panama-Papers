# %%
import pandas as pd
import zipfile
import gzip
import numpy as np

# %%
path = "D:\Python Projects\Panama Papers\\bigdata\companies.csv.gz"

# %%
zf = zipfile.ZipFile(path) 
# if you want to see all files inside zip folder
zf.namelist() 
# now read your csv file 
df = pd.read_csv(zf.open('companies.csv'))
df.head()
# Out:
# ---------------------------------------------------------------------------
# BadZipFile                                Traceback (most recent call last)
# <ipython-input-7-8e10ccbec0c3> in <module>
# ----> 1 zf = zipfile.ZipFile(path)
#       2 # if you want to see all files inside zip folder
#       3 zf.namelist()
#       4 # now read your csv file
#       5 df = pd.read_csv(zf.open('companies.csv'))
#
# ~\anaconda3\lib\zipfile.py in __init__(self, file, mode, compression, allowZip64, compresslevel, strict_timestamps)
#    1266         try:
#    1267             if mode == 'r':
# -> 1268                 self._RealGetContents()
#    1269             elif mode in ('w', 'x'):
#    1270                 # set the modified flag so central directory gets written
#
# ~\anaconda3\lib\zipfile.py in _RealGetContents(self)
#    1333             raise BadZipFile("File is not a zip file")
#    1334         if not endrec:
# -> 1335             raise BadZipFile("File is not a zip file")
# ...

# %%
count = 1
for chunk in pd.read_csv(path, compression='gzip',  chunksize=200000,low_memory=False):
    temp = chunk
    p = "openCorporate\\companiesOC" + str(count) +".csv"
    print(p)
    temp.to_csv(p)
    count += 1
    #break
# Out:
# openCorporate\companiesOC1.csv
# openCorporate\companiesOC2.csv
# openCorporate\companiesOC3.csv
# openCorporate\companiesOC4.csv
# openCorporate\companiesOC5.csv
# openCorporate\companiesOC6.csv
# openCorporate\companiesOC7.csv
# openCorporate\companiesOC8.csv
# openCorporate\companiesOC9.csv
# openCorporate\companiesOC10.csv
# openCorporate\companiesOC11.csv
# openCorporate\companiesOC12.csv
# openCorporate\companiesOC13.csv
# openCorporate\companiesOC14.csv
# openCorporate\companiesOC15.csv
# openCorporate\companiesOC16.csv
# openCorporate\companiesOC17.csv
# openCorporate\companiesOC18.csv
# openCorporate\companiesOC19.csv
# openCorporate\companiesOC20.csv
# openCorporate\companiesOC21.csv
# openCorporate\companiesOC22.csv
# openCorporate\companiesOC23.csv
# openCorporate\companiesOC24.csv
# openCorporate\companiesOC25.csv
# openCorporate\companiesOC26.csv
# openCorporate\companiesOC27.csv
# openCorporate\companiesOC28.csv
# openCorporate\companiesOC29.csv
# ...

# %%
temp.head()
# Out:
#    company_number jurisdiction_code                            name  \
# 0              ,,             us_mo          Lewis Structures, Inc.
# 1              ,-             us_mo                Site 10.01, Inc.
# 2               ,             us_mo  BHM Healthcare Solutions, Inc.
# 3   0000000000000                th                             กกก
# 4  00000000000191                br              BANCO DO BRASIL SA
#
#                          normalised_name                     company_type  \
# 0          lewis structures incorporated       Gen. Business - For Profit
# 1                site 10 01 incorporated       Gen. Business - For Profit
# 2  bhm healthcare solutions incorporated       Gen. Business - For Profit
# 3                                    กกก  Trade Association (สมาคมการค้า)
# 4                     banco do brasil sa                              NaN
#
#    nonprofit                 current_status incorporation_date  \
# ...

# %%
temp.to_csv('temp.csv')

# %%
pd.read_csv(path, compression='gzip')
# Out:
# ---------------------------------------------------------------------------
# ParserError                               Traceback (most recent call last)
# <ipython-input-18-e94d42cb5fc7> in <module>
# ----> 1 pd.read_csv(path, compression='gzip')
#
# ~\anaconda3\lib\site-packages\pandas\io\parsers.py in parser_f(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, squeeze, prefix, mangle_dupe_cols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, dialect, error_bad_lines, warn_bad_lines, delim_whitespace, low_memory, memory_map, float_precision)
#     674         )
#     675
# --> 676         return _read(filepath_or_buffer, kwds)
# ...
