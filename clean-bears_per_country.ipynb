# %%
import pandas as pd
import numpy as np
import os

# %%
fp = os.path.join('data', 'corporate_taxes.csv')
taxes = pd.read_csv(fp)
# taxes.set_index('Country')
taxes
# Out:
#                     Country Corporate tax (excl. dividend taxes)
# 0               Afghanistan                                   20
# 1                   Albania                                   15
# 2                   Algeria                                   26
# 3            American Samoa                                   34
# 4                   Andorra                                   10
# ..                      ...                                  ...
# 220  British Virgin Islands                                    0
# 221     U.S. Virgin Islands                                   10
# 222                   Yemen                                   20
# 223                  Zambia                                   35
# 224                Zimbabwe                                   25
#
# [225 rows x 2 columns]

# %%
def clean(str):
    idx = str.find('[')
    if idx != -1:
        return str[:idx]
    else:
        return str

# %%
taxes = taxes.assign(Country = taxes['Country'].apply(clean))
taxes.loc[167]
taxes
# Out:
#                     Country Corporate tax (excl. dividend taxes)
# 0               Afghanistan                                   20
# 1                   Albania                                   15
# 2                   Algeria                                   26
# 3            American Samoa                                   34
# 4                   Andorra                                   10
# ..                      ...                                  ...
# 220  British Virgin Islands                                    0
# 221     U.S. Virgin Islands                                   10
# 222                   Yemen                                   20
# 223                  Zambia                                   35
# 224                Zimbabwe                                   25
#
# [225 rows x 2 columns]

# %%
taxes.to_csv('corporate_taxes.csv')
