# %%
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.ensemble import IsolationForest

# %%
data = pd.read_csv("data/test/panama_paradise.csv")
data = data[data.node_type == "[Entity]"]
data.head()
# Out:
#    Unnamed: 0                                             entity  \
# 0           0             "A" COMPANY INTERNATIONAL EXPORT, INC.
# 1           1  "A.T.L.I." ARUBA'S TRAINING AND LANGUAGE INSTI...
# 2           2  "A.T.L.I." ARUBA'S TRAINING AND LANGUAGE INSTI...
# 3           3                         "ACRYLIC PRODUCTS LIMITED"
# 4           4                                "AEROCOSTA" EXPRESS
#
#           category node_type  pagerank  degree   country  labels
# 0  Paradise Papers  [Entity]  0.787500       0  Barbados       0
# 1  Paradise Papers  [Entity]  0.171250       0     Aruba       0
# 2  Paradise Papers  [Entity]  0.239250       0     Aruba       0
# 3  Paradise Papers  [Entity]  0.150019       0   Bahamas       0
# 4  Paradise Papers  [Entity]  0.447500       0     Aruba       0

# %%
numericalData = data[["pagerank","degree"]]
numericalData.head()
# Out:
#    pagerank  degree
# 0  0.787500       0
# 1  0.171250       0
# 2  0.239250       0
# 3  0.150019       0
# 4  0.447500       0

# %%
# Model
model=IsolationForest(n_estimators=50, max_samples='auto', contamination=float(0.1),max_features=1.0)
model.fit(numericalData)
# Out:
# IsolationForest(behaviour='deprecated', bootstrap=False, contamination=0.1,
#                 max_features=1.0, max_samples='auto', n_estimators=50,
#                 n_jobs=None, random_state=None, verbose=0, warm_start=False)

# %%
data['scores']=model.decision_function(numericalData)
data['anomaly']=model.predict(numericalData)
data.head(20)
# Out:
#     Unnamed: 0                                             entity  \
# 0            0             "A" COMPANY INTERNATIONAL EXPORT, INC.
# 1            1  "A.T.L.I." ARUBA'S TRAINING AND LANGUAGE INSTI...
# 2            2  "A.T.L.I." ARUBA'S TRAINING AND LANGUAGE INSTI...
# 3            3                         "ACRYLIC PRODUCTS LIMITED"
# 4            4                                "AEROCOSTA" EXPRESS
# 5            5             "AHI"AIRPORT HOSPITALITY INDUSTRY N.V.
# 7            7                          "AMAZONAS" SOUVENIRS SHOP
# 8            8                            "ANGEL STEPS" SHOETIQUE
# 9            9                               "ART RAP FOUNDATION"
# 10          10                                    "ARUBA SECRETS"
# 11          11                            "ARUSOLAR" CONSTRUCTION
# 12          12   "AVSERMA" AVIATION SERVICES & MANAGEMENT CO.N.V.
# 14          14                   "BALLOONS" GIFT AND PARTY CENTER
# 15          15                                    "BE-IT" LIMITED
# 16          16                     "BOUTIQUE" CAPRICHO'S FASHIONS
# 17          17                                       "BREAK TIME"
# 18          18                                   "BRILLO" CARWASH
# 19          19                                "C" BE MALL LIMITED
# 20          20                          "CALL ERNIE" CONSTRUCTION
# 21          21                                              "CAP"
#
#            category node_type  pagerank  degree                country  \
# 0   Paradise Papers  [Entity]  0.787500       0               Barbados
# 1   Paradise Papers  [Entity]  0.171250       0                  Aruba
# 2   Paradise Papers  [Entity]  0.239250       0                  Aruba
# 3   Paradise Papers  [Entity]  0.150019       0                Bahamas
# 4   Paradise Papers  [Entity]  0.447500       0                  Aruba
# 5   Paradise Papers  [Entity]  0.277500       0                  Aruba
# 7   Paradise Papers  [Entity]  0.298750       0                  Aruba
# 8   Paradise Papers  [Entity]  0.162750       0                  Aruba
# 9   Paradise Papers  [Entity]  0.532500       0                  Aruba
# 10  Paradise Papers  [Entity]  0.277500       0                  Aruba
# 11  Paradise Papers  [Entity]  0.277500       0                  Aruba
# 12  Paradise Papers  [Entity]  0.171250       0                  Aruba
# 14  Paradise Papers  [Entity]  0.168214       0                  Aruba
# 15  Paradise Papers  [Entity]  0.295664       0                  Malta
# 16  Paradise Papers  [Entity]  0.213750       0                  Aruba
# 17  Paradise Papers  [Entity]  0.277500       0                  Aruba
# 18  Paradise Papers  [Entity]  0.283295       0                  Aruba
# 19  Paradise Papers  [Entity]  0.150004       0  Saint Kitts and Nevis
# 20  Paradise Papers  [Entity]  0.277500       0                  Aruba
# 21  Paradise Papers  [Entity]  0.320000       0                  Aruba
#
#     labels    scores  anomaly
# 0        0 -0.036883       -1
# 1        0  0.092580        1
# 2        0  0.061512        1
# 3        0  0.156723        1
# 4        0  0.047555        1
# 5        0  0.129002        1
# 7        0  0.082113        1
# 8        0  0.098749        1
# 9        0  0.060730        1
# 10       0  0.129002        1
# 11       0  0.129002        1
# 12       0  0.092580        1
# 14       0  0.093761        1
# 15       0  0.093711        1
# 16       0  0.080390        1
# 17       0  0.129002        1
# 18       0  0.118474        1
# 19       0  0.157640        1
# 20       0  0.129002        1
# 21       0  0.086135        1

# %%
data.anomaly.value_counts()/len(data)
# Out:
#  1    0.90017
# -1    0.09983
# Name: anomaly, dtype: float64

# %%
data

# %%
data.anomaly = data.anomaly.map({1:0,-1:1})
data.head()
# Out:
#    Unnamed: 0                                             entity  \
# 0           0             "A" COMPANY INTERNATIONAL EXPORT, INC.
# 1           1  "A.T.L.I." ARUBA'S TRAINING AND LANGUAGE INSTI...
# 2           2  "A.T.L.I." ARUBA'S TRAINING AND LANGUAGE INSTI...
# 3           3                         "ACRYLIC PRODUCTS LIMITED"
# 4           4                                "AEROCOSTA" EXPRESS
#
#           category node_type  pagerank  degree   country  labels    scores  \
# 0  Paradise Papers  [Entity]  0.787500       0  Barbados       0 -0.036883
# 1  Paradise Papers  [Entity]  0.171250       0     Aruba       0  0.092580
# 2  Paradise Papers  [Entity]  0.239250       0     Aruba       0  0.061512
# 3  Paradise Papers  [Entity]  0.150019       0   Bahamas       0  0.156723
# 4  Paradise Papers  [Entity]  0.447500       0     Aruba       0  0.047555
#
#    anomaly
# 0        1
# 1        0
# 2        0
# 3        0
# 4        0

# %%
other = data.anomaly == data.labels

# %%
temp = data.anomaly == 1
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-22-1ee09fef5c64> in <module>
#       1 temp = data.anomaly == 1
# ----> 2 temp and other
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in __nonzero__(self)
#    1477     def __nonzero__(self):
#    1478         raise ValueError(
# -> 1479             f"The truth value of a {type(self).__name__} is ambiguous. "
#    1480             "Use a.empty, a.bool(), a.item(), a.any() or a.all()."
#    1481         )
#
# ValueError: The truth value of a Series is ambiguous. Use a.empty, a.bool(), a.item(), a.any() or a.all().

# %%
count = 0
for i in range(len(temp)):
    if temp[i] and other[i]:
        count += 1
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-23-89fbed7479f8> in <module>
#       1 count = 0
#       2 for i in range(len(temp)):
# ----> 3     if temp[i] and other[i]:
#       4         count += 1
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/series.py in __getitem__(self, key)
#     869         key = com.apply_if_callable(key, self)
#     870         try:
# --> 871             result = self.index.get_value(self, key)
#     872
#     873             if not is_scalar(result):
#
# ~/opt/anaconda3/lib/python3.7/site-packages/pandas/core/indexes/base.py in get_value(self, series, key)
#    4403         k = self._convert_scalar_indexer(k, kind="getitem")
#    4404         try:
# -> 4405             return self._engine.get_value(s, k, tz=getattr(series.dtype, "tz", None))
#    4406         except KeyError as e1:
#    4407             if len(self) > 0 and (self.holds_integer() or self.is_boolean()):
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_value()
#
# pandas/_libs/index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# pandas/_libs/hashtable_class_helper.pxi in pandas._libs.hashtable.Int64HashTable.get_item()
#
# KeyError: 6

# %%
(data.anomaly & data.labels).sum()
# Out:
# 15
